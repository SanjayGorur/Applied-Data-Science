# %%
import argparse,csv, sys, os
from datetime import date,datetime
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import numpy as np
from collections import OrderedDict,defaultdict
import pandas as pd

csv_filename = "2011.csv"
num = 10
sDate =  "2012/10/01-00:00:00"
eDate =  "2012/11/30-23:59:00"

# %%
df = pd.read_csv(csv_filename)
df.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (8,38,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    22629454  01/31/2012 11:58:14 PM  02/01/2012 04:52:27 AM   NYPD
# 1    22631407  01/31/2012 11:57:40 PM  09/10/2012 03:33:39 PM    TLC
# 2    22627727  01/31/2012 11:53:35 PM  04/01/2012 06:20:31 AM  DOHMH
# 3    22628571  01/31/2012 11:50:05 PM  02/01/2012 03:16:45 AM   NYPD
# 4    22630922  01/31/2012 11:50:00 PM  02/01/2012 05:00:00 AM    DEP
#
#                                       Agency Name       Complaint Type  \
# 0                 New York City Police Department     Blocked Driveway
# 1  Correspondence - Taxi and Limousine Commission      Taxi Compliment
# 2         Department of Health and Mental Hygiene   Food Establishment
# ...

# %%
#df = df.drop(df.columns['Agency Name'], axis=1, inplace=True)
df1 = df.loc[:,:'Incident Zip']
df2 = df.loc[:,'Latitude':'Longitude']
del df
df = pd.merge(df1, df2, left_index=True, right_index=True, how='inner')
df = df.fillna(method='pad')
df.to_csv('2011-small.csv')

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    22629454  01/31/2012 11:58:14 PM  02/01/2012 04:52:27 AM   NYPD
# 1    22631407  01/31/2012 11:57:40 PM  09/10/2012 03:33:39 PM    TLC
# 2    22627727  01/31/2012 11:53:35 PM  04/01/2012 06:20:31 AM  DOHMH
# 3    22628571  01/31/2012 11:50:05 PM  02/01/2012 03:16:45 AM   NYPD
# 4    22630922  01/31/2012 11:50:00 PM  02/01/2012 05:00:00 AM    DEP
#
#                                       Agency Name       Complaint Type  \
# 0                 New York City Police Department     Blocked Driveway
# 1  Correspondence - Taxi and Limousine Commission      Taxi Compliment
# 2         Department of Health and Mental Hygiene   Food Establishment
# 3                 New York City Police Department     Blocked Driveway
# 4          Department of Environmental Protection  Hazardous Materials
#
#             Descriptor               Location Type Incident Zip   Latitude  \
# ...
